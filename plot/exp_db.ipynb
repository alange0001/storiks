# %%
import plot
options = plot.Options(
    save=False,
    plot_nothing=True,
    plot_db=True,
    plot_pressure=True,
    print_params=False,
    print_pressure_values=True,
    db_mean_interval=2,
    plot_all_pressure=True)
exp_dir='exp_db'
exp_bs = [4,8,16,32,64,128,256,512]

# %% [markdown]
# ## YCSB Workload A

# %%
options.file_start_time[f'{exp_dir}/ycsb_wa.out.xz'] = 30
options.db_xlim = [-0.05,     60.05]
options.db_ylim = [ 0   ,  72000   ]
plot.plotFiles(
    [f'{exp_dir}/ycsb_wa.out.xz'] + [f'{exp_dir}/ycsb_wa,at3_bs{bs}_directio.out.xz' for bs in exp_bs],
    options, allfiles=f'{exp_dir}/ycsb_wa,at3_bsX_directio')
# Out:
# Graphs from file "exp_db/ycsb_wa.out.xz":
# Database Performance: exp_db/ycsb_wa.out.xz
# Pressure: exp_db/ycsb_wa.out.xz
# Graphs from file "exp_db/ycsb_wa,at3_bs4_directio.out.xz":
# Database Performance: exp_db/ycsb_wa,at3_bs4_directio.out.xz
# Pressure: exp_db/ycsb_wa,at3_bs4_directio.out.xz
# Pressure values: w0=0.000, w1=0.069, w2=0.067, w3=0.085, w4=0.129, w5=0.701, w6=0.798, w7=0.841, w8=0.865, w9=0.880, w10=0.890, w11=0.891, w12=0.901, w13=0.903, w14=0.901, w15=0.907, w16=0.909, w17=0.907, w18=0.914, w19=0.910, w20=0.918, w21=0.918, w22=0.919, w23=0.924, w24=0.921, w25=0.926
# Graphs from file "exp_db/ycsb_wa,at3_bs8_directio.out.xz":
# Database Performance: exp_db/ycsb_wa,at3_bs8_directio.out.xz
# Pressure: exp_db/ycsb_wa,at3_bs8_directio.out.xz
# ...

# %% [markdown]
# ## YCSB workload B

# %%
options.file_start_time[f'{exp_dir}/ycsb_wb.out.xz'] = 30
options.db_xlim = [-0.05,      60.05]
options.db_ylim = [ 0   ,  125000   ]
plot.plotFiles(
    [f'{exp_dir}/ycsb_wb.out.xz'] + [f'{exp_dir}/ycsb_wb,at3_bs{bs}_directio.out.xz' for bs in exp_bs],
    options, allfiles=f'{exp_dir}/ycsb_wb,at3_bsX_directio')
# Out:
# Graphs from file "exp_db/ycsb_wb.out.xz":
# Database Performance: exp_db/ycsb_wb.out.xz
# Pressure: exp_db/ycsb_wb.out.xz
# Graphs from file "exp_db/ycsb_wb,at3_bs4_directio.out.xz":
# Database Performance: exp_db/ycsb_wb,at3_bs4_directio.out.xz
# Pressure: exp_db/ycsb_wb,at3_bs4_directio.out.xz
# Pressure values: w0=0.000, w1=0.073, w2=0.036, w3=0.061, w4=0.112, w5=0.767, w6=0.855, w7=0.892, w8=0.912, w9=0.924, w10=0.930, w11=0.930, w12=0.933, w13=0.936, w14=0.938, w15=0.939, w16=0.940, w17=0.941, w18=0.943, w19=0.945, w20=0.948, w21=0.950, w22=0.951, w23=0.950, w24=0.951, w25=0.952
# Graphs from file "exp_db/ycsb_wb,at3_bs8_directio.out.xz":
# Database Performance: exp_db/ycsb_wb,at3_bs8_directio.out.xz
# Pressure: exp_db/ycsb_wb,at3_bs8_directio.out.xz
# ...

# %% [markdown]
# ## db_bench workload readwhilewriting

# %%
options.file_start_time[f'{exp_dir}/dbbench_wwr.out.xz'] = 30
options.db_xlim = [-0.05,      60.05]
options.db_ylim = [ 0   ,  170000   ]
plot.plotFiles(
    [f'{exp_dir}/dbbench_wwr.out.xz'] + [f'{exp_dir}/dbbench_wwr,at3_bs{bs}_directio.out.xz' for bs in exp_bs],
    options, allfiles=f'{exp_dir}/dbbench_wwr,at3_bsX_directio')
# Out:
# Graphs from file "exp_db/dbbench_wwr.out.xz":
# Database Performance: exp_db/dbbench_wwr.out.xz
# Pressure: exp_db/dbbench_wwr.out.xz
# Graphs from file "exp_db/dbbench_wwr,at3_bs4_directio.out.xz":
# Database Performance: exp_db/dbbench_wwr,at3_bs4_directio.out.xz
# Pressure: exp_db/dbbench_wwr,at3_bs4_directio.out.xz
# Pressure values: w0=0.000, w1=0.021, w2=0.024, w3=0.006, w4=0.017, w5=0.642, w6=0.782, w7=0.828, w8=0.835, w9=0.856, w10=0.866, w11=0.871, w12=0.873, w13=0.863, w14=0.861, w15=0.852, w16=0.848, w17=0.845, w18=0.843, w19=0.839, w20=0.845, w21=0.841, w22=0.845, w23=0.847, w24=0.849, w25=0.852
# Graphs from file "exp_db/dbbench_wwr,at3_bs8_directio.out.xz":
# Database Performance: exp_db/dbbench_wwr,at3_bs8_directio.out.xz
# Pressure: exp_db/dbbench_wwr,at3_bs8_directio.out.xz
# ...
